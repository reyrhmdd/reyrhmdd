# %% [markdown]
# **REYNALDI RAHMAD_122450088_RA**
#
# **Membuat visualisasi data lebih efisien dan efektif: survei**
# Visualisasi data, yang mengubah data abstrak menjadi visi fisik (misalnya panjang, posisi, bentuk, warna, dan sebagainya), merupakan sarana ampuh untuk menyajikan kisah data yang menarik kepada manusia yang lebih berorientasi visual. Saat ini, semua organisasi memiliki lebih banyak data dibandingkan sebelumnya.
# Akibatnya, semakin banyak organisasi yang menggunakan data dan analisis tingkat lanjut untuk menginformasikan keputusan strategis dan operasional. Visualisasi data sangat cocok untuk memberikan gambaran umum yang baik tentang data yang sangat besar, dan mempermudah interpretasi hasil analisis data kepada ilmuwan data
#
# **Alur Visualisasi Data:**
# 1. **Impor Data:** Pengambilan data dari sumber yang diinginkan.
# 2. **Persiapan Data:** Pembersihan dan normalisasi data yang diimpor, serta interpolasi nilai yang hilang.
# 3. **Manipulasi Data:** Seleksi dan penyaringan data yang relevan, penggabungan, serta pengelompokan data.
# 4. **Pemetaan:** Konversi data ke dalam geometri visual primitif (titik, garis) dan atributnya (warna, posisi).
# 5. **Rendering:** Konversi geometri visual menjadi representasi visual akhir.
#
# **Komponen Kritis:**
# - **Manipulasi Data dan Pemetaan:** Efisiensi dalam dua langkah ini sangat penting. Sistem seperti mesin penghenti (menerjemahkan kueri visualisasi ke kueri SQL) dan solusi perkiraan/progresif digunakan untuk menangani data besar dan memberikan respons waktu nyata.
#
# **Rekomendasi Visualisasi Data:**
# - **Tantangan:** Menentukan visualisasi yang tepat seringkali merupakan proses coba-coba, bahkan untuk ahli. Penting bagi sistem visualisasi untuk memberikan panduan dan rekomendasi.
# - **Pendekatan:** Beberapa sistem otomatisasi visualisasi memungkinkan pengguna memberikan spesifikasi yang ambigu dan secara otomatis menyelesaikan visualisasi atau memberikan rekomendasi.
#
# **Arah Pengembangan Efisiensi:**
# 1. **Spesifikasi Visualisasi:** Memfasilitasi berbagai cara bagi pengguna untuk menentukan visualisasi yang diinginkan. Penelitian berfokus pada bahasa visualisasi dan teknik pemetaan informasi ke elemen visual.
# 2. **Pendekatan Efisien:**
#    - **Integrasi Sistem:** Mengintegrasikan database, visualisasi data, dan analisis untuk kemudahan penggunaan dalam satu sistem.
#    - **Teknik Efisiensi:** Teknik yang meningkatkan efisiensi dalam proses eksplorasi data dan visualisasi, dengan fokus pada bagaimana membuat visualisasi secara efisien.
#
# **Survei dan Literatur Terkait:**
# - **Spesifikasi Visualisasi:** Berbagai survei telah membahas bahasa visualisasi dari perspektif klasifikasi, media presentasi, dan aplikasi praktis.
# - **Pendekatan Efisien:** Studi tentang integrasi sistem dan teknik efisiensi dalam visualisasi data mencakup penanganan data besar dan pengembangan tek
# n**2	Spesifikasi visualisasi**
# **
# 2.1	Spesifikasi visualisasi dat**a
#
# Secara umum, bahasa visualisasi data terdiri dari tiga bagian: data, tanda (atau isyarat visual), dan pemetaan di antara keduan
#
# **2.2 Kategorisasi Bahasa Visualisasi Data**
#
# **Jenis Bahasa Visualisasi Data:**
#
# **Bahasa Visualisasi Tingkat Rendah:**
#
# Contoh: Prefuse, Flare
# Fitur:
# Menggunakan kelas Java dengan atribut visual.
# Memerlukan pengguna untuk menentukan semua elemen pemetaan secara manual.
# Memberikan fleksibilitas tinggi dalam pemetaan data ke atribut visual, tetapi lebih kompleks dan memerlukan pemahaman yang mendalam.
# Bahasa Visualisasi Tingkat Tinggi:
#
# Contoh: ggplot2, Vega-Lite, Altair, Echarts, VizQL
# Fitur:
# Menyederhanakan proses pembuatan visualisasi dengan menyediakan abstractions dan default sensitif.
# Mengurangi kebutuhan untuk menentukan detail tingkat rendah.
# Mempermudah pengguna dengan menyediakan templat dan fungsionalitas siap pakai.
# Memungkinkan desain visualisasi dengan tata bahasa yang lebih ringkas dan interaktif.
# Bahasa Visualisasi Spesifik:
#
# Proto-vis: Perangkat grafis berbasis JavaScript dengan pendekatan deklaratif dan atribut visual sederhana.
# D3: Pengembangan dari Proto-vis, lebih efektif dalam menangani interaksi pengguna seperti penyaringan dan penghubungan.
# Vega dan Reaktif Vega: Mirip dengan Protovis dan D3, tetapi dengan tata bahasa deklaratif yang dapat disusun untuk interaksi.
# ggplot2: Berdasarkan "The Grammar of Graphics" oleh Wilkinson, menggunakan tata bahasa grafis berlapis di R.
# Vega-Lite: Pengembangan dari Vega dan Reaktif Vega, mendukung desain interaksi yang dapat disusun dengan tata bahasa ringkas.
# Altair: Implementasi Vega-Lite untuk Python.
# Echarts: Bahasa visualisasi deklaratif yang mendukung pembuatan visualisasi cepat, dirancang untuk non-programmer.
# VizQL: Berkembang dari sistem Polaris, memungkinkan visualisasi berbasis kueri dengan fokus pada interaktivitas.
# Dimensi Kategorisasi:
#
# Ekspresifitas: Bahasa tingkat rendah lebih ekspresif karena memberikan kontrol detail penuh atas pemetaan data, sedangkan bahasa tingkat tinggi menyederhanakan pembuatan visualisasi dengan default dan templat.
# Aksesibilitas: Bahasa tingkat tinggi lebih mudah digunakan karena menyediakan abstractions dan batasan yang mengurangi kompleksitas bagi pengguna.
# Bahasa visualisasi data dikategorikan berdasarkan tingkat ekspresifitas dan aksesibilitasnya, dari kontrol penuh di tingkat rendah hingga kemudahan penggunaan di tingkat tinggi.y
# **2.3	Operasi visual berbasis GUI**
#
# Dibandingkan dengan menggunakan bahasa visualisasi deklaratif
# tentukan visualisasi seperti yang dibahas dalam Bagian. 2.2, cara yang lebih mudah digunakan dalam memberikan spesifikasi adalah dengan mengikuti "prinsip manipulasi langsu74, sebuah konsep yang banyak digunakan dalam aspek interaksi manusia-kompu.
#
# **2.4	Spesifikasi yang tidak ditentukan**
# t
# Visualisasi tidak ada artinya jika tidak dapat memberikan wawasan tentang data. Namun, dalam banyak kasus, pengguna tidak benar-benar mengetahui seluruh aspek data yang ada, karena datanya mungkin besar dan datanya sering diperbarui. Oleh karena itu, hal ini menimbulkan persyaratan untuk mendukung spesifikasi yang tidak ditentukan.
# Secara umum, untuk spesifikasi yang tidak ditentukan, pengguna hanya memberikan beberapa “petunjuk”, dan merupakan tugas sistem visualisasi untuk menafsirkan masukan yang tidak ditentukan, dengan (mungkin) cara yang berbeda.
#
# Jenis petunjuk pertama adalah “berbasis referensi”, di mana pengguna memberikan visualisasi referensi sebagai benih dan sistem menyarankan visualisasi berdasarkan referensi tersebut. zen-vis. 6 mengembalikan visualisasi serupa atau berbeda (misalnya, tren serupa dalam diagram garis) dengan visualisasi referensi yang disediakan penggun
# **3 Pendekatan efisien untuk visualisasi data**
# **3.1 visualisasi data yang tepat**
#
# Banyak sistem visualisasi data. membaca data dari database.
# Mereka juga dapat memanipulasi data dengan pernyataan SQL dan kemudian menggunakan alat visualisasi untuk merender visualisasi tersebut.
#
# Terjemahan Kueri Cara alami untuk menggunakan kembali banyak sistem yang sudah matang (DBMS) adalah dengan menerjemahkan kueri visualisasi ke kueri yang diterima sistem tersebut. Misalnya, Deep, Pola20, Se23 mendapatkan data dengan mengeluarkan kueri SQL ke database. Dengan membuat pemetaan antara bahasa visualisasi primitif dan bahasa SQL, kita dapat mengubah bahasa visualisasi target menjadi kueri S
#
# **3.2 perkiraan visualisasi data**
# QKetika volume data tumbuh secara eksponensial, data tradisional
# modul pemrosesan tidak dapat memberikan hasil pemrosesan interaktif yang cepat. Untuk menjembatani kesenjangan antara volume data dan interaktivitas, banyak pekerjaan mempercepat fase pemrosesan data dengan memanfaatkan perkiraan pemrosesan kueri (AQP)
# yang memberikan perkiraan hasil visualisasi.
# Kami membahas perkiraan visualisasi data dari tiga perspektif: Pendekatan berbasis AQP yang memanfaatkan teknik
# dari AQP; pendekatan berbasis pengambilan sampel tambahan yang menghubungkan
# pemrosesan kueri tambahan hingga visualisasi; dan manusia
# pendekatan berbasis persepsi yang menangkap keterbatasan kognitif persepsi ma
#
# **3.3 visualisasi data progresif**
#
# Binning Berbasis Rentang imMens [31] menyediakan visualisasi resolusi berbeda dengan mengubah ukuran bin. Tempat sampah dengan resolusi yang sama memiliki rentang yang sama. Data multidimensi di imMens dipartisi menjadi kubus data, dan kubus dipartisi menjadi ubin dengan level berbeda. Pengguna dapat menjelajahi data di berbagai level dan mengubah resolusi visualisasi yang sedang dieksplorasi dengan memperbesar atau memperkecil, lalu, sistem akan mengubah ukuran wadah agregasi yang mendasarinya. imMens membuang data numerik dengan rentang yang sama, yang memiliki beberapa keterbatasan. Misalnya, dengan mempertimbangkan kumpulan
# data transkrip ujian, pengelompokan dengan rentang skor yang sama tidak berlaku jika guru ingin mengetahui siswa 10 teratas, 10 hingga 20 teratas, 20 hingga 30 siswa teratas, dll. Selain itu, pengguna tidak dapat mengubah ukuran bin atau jumlah resolusi berbeda di imMens.
#
# **4 rekomendasi visualisasi**
# **4.1 rekomendasi berdasarkan spesifikasi**
# Sistem rekomendasi visualisasi dengan spesifikasi kosong tidak memerlukan masukan pengguna, sedangkan sistem rekomendasi dengan spesifikasi parsial menerima masukan spesifikasi elemen visualisasi parsial pengguna untuk visualisasi yang diinginkan. Misalnya, APT [88] menerima tujuan melihat data pengguna sebelumnya
#
# **4.2 rekomendasi berbasis perilaku**
#
# Sistem rekomendasi berbasis perilaku menangkap perilaku pengguna saat ini sebagai masukan, kemudian menyimpulkan tugas yang diinginkan pengguna dan
# merekomendasikan visualisasi yang berguna berdasarkan tugas mereka.
# HARVEST [134] adalah sistem rekomendasi visualisasi berbasis perilaku.
# Ini merekomendasikan visualisasi berdasarkan
# tugas pengguna yang disimpulkan oleh perilaku mereka. sejak
# sulit bagi pengguna untuk menggambarkan maksudnya dengan jelas dan tugas pengguna berkembang seiring proses eksplorasi, HAR-VEST menebak maksud pengguna berdasarkan perilaku mereka. Seperti yang ditunjukkan di Ara. 14, saat pengguna berinteraksi dengan HARVEST di depan akhir, ia menangkap tindakan pengguna ÿi dan mengirimkannya ke back-end.Ada beberapa tindakan atom umum yang dipelajari oleh HAR-VEST: inspeksi, filter, dan bookmark. Atom tindakan membentuk pola yang kompleks, yang biasanya menunjukkan niat tertentu. Selanjutnya, modul Action Tracker (Gbr. 14-ÿ) enganalisis dan menampilkan konteks dan pola tugas pengguna
# pi berdasarkan tindakan yang diterima. Lebih konkretnya, ci menunjukkan upaya HARVEST mendefinisikan 4 pola: scan, flip, swap, dan menelusuri. Kemudian, HARVEST dapat merekomendasikan visualisasi berdasarkan pola yang disimpulkan pengguna
#
# **4.3 rekomendasi yang dipersonalisasi**
# Sistem rekomendasi yang dipersonalisasi menangkap riwayat perilaku pengguna sebagai masukan untuk merekomendasikan visualisasi menarik yang dipersonalisasi.
# Model Linier VizDeck [84] memberikan hasil rekomendasi visualisasi yang dipersonalisasi dengan melatih model linier
# setiap pengguna menggunakan perilaku historisnya. VizDeck menyediakan desain antarmuka baru yang menampilkan top-k direkomendasikan visualisasi kepada pengguna dalam grid. Elemen yang ditampilkan di
# grid disebut vizlet. Pengguna dapat menelusuri, menjatuhkan, mempromosikan atau susun ulang vizlet, dan vizlet terakhir yang dipilih akan ditampilkan di
# dasbor interaktif. VizDeck bisa mendapatkan pengguna
# preferensi visualisasi berdasarkan perilaku historis mereka selama eksplorasi, mengekstrak fitur untuk vizlet ini, dan kemudian
# melatih model linier yang mencetak poin untuk rekomendasi di masa mendatang.
#
#
# **4.4 ringkasan**
# Sistem rekomendasi visualisasi dengan spesifikasi kosong, seperti Draco [35], Data2Vis [120] dan Rank-by-feature [38], sangat membantu pengguna untuk menjelajahi data dengan cepat
# ketika pengguna tidak terlalu paham dengan data dan diinginkan visualisasi Sebagian besar sistem rekomendasi yang ada
# memerlukan spesifikasi parsial, karena mengizinkan spesifikasi pengguna untuk visualisasi yang diinginkan sebagai masukan, misalnya kata kunci spesifikasi di DeepEye [17,32]. Solusi berbasis aturan sudah ada
# sejalan dengan pemahaman intuitif seseorang tentang visualisasi,
# namun tidak memberikan pemahaman yang lengkap tentang persepsi manusia, hanya berfokus pada beberapa metrik yang diminati. Mesin
# solusi berbasis pembelajaran perlu mengumpulkan data pelatihan, dan
# hasilnya sulit untuk diinterpretasikan, tetapi mungkin dapat menangkap gambaran manusia
# pengetahuan kognitif tentang efektivitas visualisasi. Dan
# model pembelajaran akan menjadi lebih pintar bila semakin banyak pelatihan
# data dikumpulkan.
#
# **5 arah penelitian lainnya**
# **5.1 persiapan data untuk visualisasi data**
# Data di kehidupan nyata biasanya kotor, dan memvisualisasikan data kotor dapat menyesatkan pengguna. Fenomena ini sudah dikenal sejak lama sebagai salah satu jenis visualisasi bias dari komunitas visualisasi data.
# Misalnya, kumpulan data yang terintegrasi dari berbagai sumber mungkin berisi duplikat.
# Secara alami, data yang divisualisasikan harus dibersihkan, seperti normalisasi nilai, deduplikasi, imputasi nilai yang hilang, dan deteksi outlier. Tableau
# telah mengintegrasikan Trifacta untuk persiapan data di seluruh kumpulan data. Penelitian berikut telah dilakukan, baik dari komunitas database maupun komunitas visualisasi, untuk menyelidiki dampak data kotor pada visualisasi data.
#
# **5.2 tolok ukur visualisasi**
# Seperti ImageNet atau tolok ukur TPC klasik, penting untuk mengembangkan tolok ukur kinerja dan rekomendasi. Tolok ukur harus sesuai dengan tugas analisis visual, memberikan jejak dan data yang dapat digunakan kembali, dan jika direkomendasikan, memiliki cakupan dan kualitas label yang tinggi
#
# **5.3 visualisasi data untuk aplikasi terkait database**
# Seperti disebutkan sebelumnya di Sekte. 1, visualisasi data juga memainkan peran penting dalam aplikasi terkait database, seperti Excel [9], Google Sheets [10], Oracle Data Visualization Desktop [11], IBM Db2 [12], Amazon Quicksight [13].
